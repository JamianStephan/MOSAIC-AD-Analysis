# %%
from AD_analysis import *
import Atmospheric_diffraction as atm_shift
import numpy as np
import matplotlib as mpl
import Integ_analysis as int_analysis
import Transmission_calculation as trans_calc
import pandas as pd

# %%
metrics=pd.read_csv("generic_test_cases_v4.csv")

# %%
fig, ax = plt.subplots(figsize=(6, 10))
plt.xlim(-0.5,4.5)

for i in range(0,105):
    HA_mid=metrics.at[i,'HA mid']

    targ_dec=metrics.at[i,'Dec']
    centring="mid HA"
    VIS_band=metrics.at[i,'VIS band']
    VIS_centre=metrics.at[i,'VIS Centre']
    NIR_centre=metrics.at[i,'NIR Centre']
    guide=metrics.at[i,'Guide']

    plt.scatter(HA_mid,targ_dec,color='black',marker="x",alpha=0)
    ax.text(HA_mid-0.1,targ_dec-0.6,guide)
plt.title("VIS B + NIR All Optimised Guide")
plt.xlabel("Integration HA midpoint (h)")
plt.ylabel("Declination (deg)")
# Out:
# Text(0, 0.5, 'Declination (deg)')

# %%
fig, ax = plt.subplots(figsize=(6, 10))
plt.xlim(-0.5,4.5)

for i in range(105,210):
    HA_mid=metrics.at[i,'HA mid']

    targ_dec=metrics.at[i,'Dec']
    centring="mid HA"
    VIS_band=metrics.at[i,'VIS band']
    VIS_centre=metrics.at[i,'VIS Centre']
    NIR_centre=metrics.at[i,'NIR Centre']
    guide=metrics.at[i,'Guide']

    plt.scatter(HA_mid,targ_dec,color='black',marker="x",alpha=0)
    ax.text(HA_mid-0.1,targ_dec-0.6,guide)
plt.title("VIS G + NIR All Optimised Guide")
plt.xlabel("Integration HA midpoint (h)")
plt.ylabel("Declination (deg)")
# Out:
# Text(0, 0.5, 'Declination (deg)')

# %%
fig, ax = plt.subplots(figsize=(6, 10))
plt.xlim(-0.5,4.5)

for i in range(210,315):
    HA_mid=metrics.at[i,'HA mid']

    targ_dec=metrics.at[i,'Dec']
    centring="mid HA"
    VIS_band=metrics.at[i,'VIS band']
    VIS_centre=metrics.at[i,'VIS Centre']
    NIR_centre=metrics.at[i,'NIR Centre']
    guide=metrics.at[i,'Guide']

    plt.scatter(HA_mid,targ_dec,color='black',marker="x",alpha=0)
    ax.text(HA_mid-0.1,targ_dec-0.6,guide)
plt.title("VIS R + NIR All Optimised Guide")
plt.xlabel("Integration HA midpoint (h)")
plt.ylabel("Declination (deg)")
# Out:
# Text(0, 0.5, 'Declination (deg)')
