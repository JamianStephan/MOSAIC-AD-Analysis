# %%
import dispersion_analysis as disp
from matplotlib import pyplot as plt

# %%
simulation=disp.AD_simulation(simulation_scale=0.01)
simulation.load_hour_angles([1,1.5,2],-30)
simulation.load_wavelengths([.6,.7,.8,.9,1])
simulation.calculate_integration_shifts(.7,.8)
simulation.load_aperture(.6)
simulation.load_PSFs()
simulation.calculate_snapshot_transmissions()
simulation.snapshot_plots(y_axis='relative')
simulation.calculate_integration_transmissions()
simulation.integration_plots(y_axis='relative',track_indexes=[0,int(len(simulation.output['wavelengths'])/2),-1])
